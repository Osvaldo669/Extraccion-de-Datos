# %%
import pandas as pds
import numpy as np
import os

datos = pds.read_csv(r"Document\\covid_19_data.csv")
pais = datos.groupby('Country/Region')[['Confirmed','Deaths']].sum()
resultado = pais.nlargest(10, 'Confirmed')
print(resultado)
resultado.plot(kind='bar')
# Out:
#                 Confirmed   Deaths
# Country/Region
# Mainland China  1989706.0  58977.0
# South Korea       31042.0    191.0
# Italy             13289.0    374.0
# Others            12898.0     59.0
# Iran               9354.0    460.0
# Japan              3566.0     52.0
# Singapore          2282.0      0.0
# Hong Kong          2009.0     45.0
# Germany            1325.0      0.0
# France             1306.0     32.0
# <AxesSubplot:xlabel='Country/Region'>
